# %% [markdown]
# # " WEB SCRAPER "

# %% [markdown]
# - Initailisation of the web scrapper
# - Request of the url's HTML page
# - Initalisation of the HTML parser with the known page coding

# %%
import requests
from bs4 import BeautifulSoup as soup

url = 'https://www.psp.cz/sqw/hlasy.sqw?g=67018'
connection = requests.get(url)
htmlpage = connection.content.decode('cp1250')
connection.close()

parser = soup(htmlpage, "html.parser")

# %% [markdown]
# **Analysing the HTML tags for scraping the required data**

# %%
czech_english = {
    # months
    'ledna' : '1',
    'února' : '2',
    'března' : '3',
    'dubna' : '4',
    'května' : '5',
    'června' : '6',
    'července' : '7',
    'srpna' : '8',
    'září' : '9',
    'října' : '10',
    'listopadu' : '11',
    'prosince' : '12',
    # decisions
    'NÁVRH BYL PŘIJAT' : 'ACCEPTED',
    'NÁVRH BYL ZAMÍTNUT' : 'REJECTED'
}

# MEETING INFO - (NO.) MEETING, (NO.) VOTE, (DAY) (MONTH) (YEAR), (TIME)(MEETING NAME)
meeting_info = parser.h1.text
meeting_details = meeting_info.split(',')
meeting_no = meeting_details[0].strip().split('.')[0]
vote_no = meeting_details[1].strip().split('.')[0]
meeting_date = meeting_details[2].strip()
meeting_day = meeting_date.split('.')[0]
meeting_month = meeting_date.split('.')[1].split('\xa0')[1]
meeting_month = czech_english.get(meeting_month, meeting_month)
meeting_year = meeting_date.split('.')[1].split('\xa0')[2]
meeting_name = meeting_details[3][6:]


# MEETING DECISION
meeting_summary = parser.findAll("div", class_="summary")[0]
meeting_decision = meeting_summary.h2.span.text
meeting_decision = czech_english.get(meeting_decision, meeting_decision)

# PRESENT VOTES / MINIMUM REQUIRED VOTES RATIO
meeting_voting_presence = meeting_summary.p
present_votes = meeting_voting_presence.findAll("strong")[0].text
min_votes = meeting_voting_presence.findAll("strong")[1].text

# TOTAL VOTE RATIOS
try:
    meeting_voter_ratio = parser.findAll("tr", bgcolor="#ccffcc")[0]
except:
    meeting_voter_ratio = parser.findAll("tr", bgcolor="#ffcccc")[0]    
total_deputies = meeting_voter_ratio.findAll("td")[1].text
total_yes = meeting_voter_ratio.findAll("td")[2].text
total_no = meeting_voter_ratio.findAll("td")[3].text
total_na = meeting_voter_ratio.findAll("td")[4].text
total_stayed = meeting_voter_ratio.findAll("td")[5].text
total_sorry = meeting_voter_ratio.findAll("td")[6].text

print('\n= MEETING NAME = ' + meeting_name )
print('\n= MEETING DATE = ' + meeting_date )
print('\n= MEETING DAY = ' + meeting_day )
print('\n= MEETING MONTH = ' + meeting_month )
print('\n= MEETING YEAR = ' + meeting_year )
print('\n= MEETING NO = ' + meeting_no )
print('\n= VOTE NO = ' + vote_no )
print('\n= MEETING DECISION = ' + meeting_decision )
print('\n= PRESENT VOTES = ' + present_votes )
print('\n= MIN NO. VOTES = ' + min_votes )
print('\n= MEETING VOTER RATIO =')
print('TOTAL DEPUTIES = ' + total_deputies )
print('TOTAL YES = ' + total_yes )
print('TOTAL NO = ' + total_no )
print('TOTAL NOT AVAILABLE = ' + total_na )
print('TOTAL STAYED = ' + total_stayed )
print('TOTAL SORRY = ' + total_sorry )

vote_dictionary = {
    'A' : 'YES',
    'N' : 'NO',
    '0' : 'NOT AVAILABLE',
    'Z' : 'STAYED',
    'M' : 'SORRY'
}

# PARLIAMENTARY CLUB NAMES ( 1 - 9 ) & SUMMARY OF VOTES 
i = -1
for parliamentary in parser.findAll("h2", class_="section-title center")[1:10]:
    i += 1
    parl = parliamentary.text
    parl_name = parl.split('(')[0]
    print(f'\n===== {parl_name}=====')
    for deputy in parser.findAll("ul", class_="results")[i]:
        deputy_name = deputy.a.text
        deputy_vote = deputy.span.text
        deputy_vote = vote_dictionary.get(deputy_vote, deputy_vote)
        print(f'= {deputy_name} = {deputy_vote}')
# Out:
# = MEETING NAME = Inf. o ustavení volební komise PS a volbě členů
#
# = MEETING DATE = 20. listopadu 2017
#
# = MEETING DAY = 20
#
# = MEETING MONTH = 11
#
# = MEETING YEAR = 2017
#
# = MEETING NO = 1
#
# = VOTE NO = 1
#
# = MEETING DECISION = ACCEPTED
#
# = PRESENT VOTES = 196
#
# = MIN NO. VOTES = 99
#
# = MEETING VOTER RATIO =
# TOTAL DEPUTIES = 200
# TOTAL YES = 191
# TOTAL NO = 0
# TOTAL NOT AVAILABLE = 3
# TOTAL STAYED = 5
# TOTAL SORRY = 1
#
# ===== ANO =====
# = Věra Adámková = YES
# = Andrej Babiš = YES
# = Andrea Babišová = YES
# = Margita Balaštíková = YES
# = Josef Bělica = YES
# = Stanislav Berkovec = YES
# = Jiří Bláha = YES
# = Richard Brabec = YES
# = Milan Brázdil = STAYED
# = Andrea Brzobohatá = YES
# = Jaroslav Bžoch = YES
# = Klára Dostálová = YES
# = Lenka Dražilová = YES
# = Jaroslav Faltýnek = YES
# = Kamal Farhan = YES
# = Milan Feranec = YES
# = Eva Fialová = YES
# = Stanislav Fridrich = YES
# = Josef Hájek = YES
# = Jiří Hlavatý = YES
# = Milan Hnilička = YES
# = Ivan Jáč = NOT AVAILABLE
# = Miloslav Janulík = YES
# = Aleš Juchelka = YES
# = Pavel Juříček = YES
# = Adam Kalous = YES
# = David Kasal = YES
# = Tomáš Kohoutek = YES
# = Martin Kolovratník = YES
# = Barbora Kořanová = YES
# = Josef Kott = YES
# = Robert Králíček = YES
# = Roman Kubíček = YES
# = Jan Kubík = YES
# = Jaroslav Kytýr = YES
# = Taťána Malá = YES
# = Přemysl Mališ = YES
# = Jiří Mašek = YES
# = Radka Maxová = YES
# = Marcela Melková = YES
# = Jana Mračková Vildumetzová = NOT AVAILABLE
# = Patrik Nacher = YES
# = Marek Novák = YES
# = Monika Oborná = YES
# = Ladislav Okleštěk = YES
# = Zuzana Ožanová = YES
# = Jana Pastuchová = YES
# = Robert Pelikán = YES
# = František Petrtýl = YES
# = Pavel Plzák = YES
# = Jaroslava Pokorná Jermanová = YES
# = David Pražák = YES
# = Věra Procházková = YES
# = Pavel Pustějovský = YES
# = Karel Rais = YES
# = Michal Ratiborský = YES
# = Jan Richter = YES
# = Miloslava Rutová = YES
# = Pavel Růžička = YES
# = Jan Řehounek = YES
# = Petr Sadovský = YES
# = Jan Schiller = YES
# = Pavel Staněk = YES
# = Martin Stropnický = YES
# = Jiří Strýček = YES
# = Karla Šlechtová = YES
# = Julius Špičák = YES
# = David Štolpa = YES
# = Dan Ťok = YES
# = Karel Tureček = YES
# = Helena Válková = YES
# = Adam Vojtěch = YES
# = Jan Volný = YES
# = Radek Vondráček = STAYED
# = Ivo Vondrák = YES
# = Petr Vrána = YES
# = Rostislav Vyzula = YES
# = Radek Zlesák = YES
#
# ===== ODS =====
# = Ivan Adamec = YES
# = Jan Bauer = YES
# = Martin Baxa = YES
# = Petr Beitl = YES
# = Marek Benda = YES
# = Stanislav Blaha = YES
# = Pavel Blažek = YES
# = Jana Černochová = YES
# = Petr Fiala = YES
# = Jakub Janda = NOT AVAILABLE
# = Václav Klaus = YES
# = Karel Krejza = YES
# = Martin Kupka = YES
# = Zuzana Majerová Zahradníková = YES
# = Jaroslav Martinů = YES
# = Ilona Mauritzová = YES
# = Vojtěch Munzar = YES
# = Miroslava Němcová = YES
# = Jan Skopeček = YES
# = Zbyněk Stanjura = YES
# = Bohuslav Svoboda = YES
# = Jiří Ventruba = YES
# = Veronika Vrecionová = YES
# = Jan Zahradník = YES
# = Pavel Žáček = YES
#
# ===== Piráti =====
# = Dana Balcarová = YES
# = Lukáš Bartoň = YES
# = Ivan Bartoš = YES
# = Lukáš Černohorský = YES
# = František Elfmark = YES
# = Mikuláš Ferjenčík = YES
# = Radek Holomčík = YES
# = Martin Jiránek = YES
# = Lukáš Kolářík = YES
# = František Kopřiva = YES
# = Lenka Kozlová = YES
# = Jan Lipavský = YES
# = Tomáš Martínek = YES
# = Jakub Michálek = YES
# = Mikuláš Peksa = YES
# = Vojtěch Pikal = YES
# = Ondřej Polanský = YES
# = Jan Pošvář = YES
# = Ondřej Profant = YES
# = Olga Richterová = YES
# = Petr Třešňák = YES
# = Tomáš Vymazal = YES
#
# ===== SPD =====
# = Marian Bojko = YES
# = Jaroslav Dvořák = YES
# = Radim Fiala = YES
# = Jaroslav Holík = YES
# = Jan Hrnčíř = YES
# = Tereza Hyťhová = YES
# = Monika Jarošová = YES
# = Pavel Jelínek = YES
# = Jiří Kobza = YES
# = Jiří Kohoutek = YES
# = Radek Koten = YES
# = Jana Levová = YES
# = Karla Maříková = YES
# = Ivana Nevludová = YES
# = Tomio Okamura = YES
# = Zdeněk Podal = YES
# = Miloslav Rozner = YES
# = Radek Rozvoral = YES
# = Lucie Šafránková = YES
# = Lubomír Španěl = YES
# = Radovan Vích = YES
# = Lubomír Volný = YES
#
# ===== ČSSD =====
# = Jiří Běhounek = YES
# = Jan Birke = YES
# = Petr Dolínek = YES
# = Jaroslav Foldyna = STAYED
# = Alena Gajdůšková = YES
# = Jan Hamáček = YES
# = Tomáš Hanzel = YES
# = Milan Chovanec = STAYED
# = Jan Chvojka = YES
# = Roman Onderka = YES
# = Bohuslav Sobotka = YES
# = Antonín Staněk = YES
# = Kateřina Valachová = YES
# = Ondřej Veselý = YES
# = Lubomír Zaorálek = YES
#
# ===== KSČM =====
# = Hana Aulická Jírovcová = YES
# = Alexander Černý = YES
# = Jiří Dolejš = SORRY
# = Vojtěch Filip = YES
# = Miroslav Grebeníček = YES
# = Stanislav Grospič = YES
# = Vladimír Koníček = YES
# = Pavel Kováčik = YES
# = Leo Luzar = YES
# = Květa Matušovská = YES
# = Zdeněk Ondráček = YES
# = Daniel Pawlas = YES
# = Ivo Pojezný = YES
# = Jiří Valenta = YES
# = Miloslava Vostrá = YES
#
# ===== KDU-ČSL =====
# = Jan Bartošek = YES
# = Pavel Bělobrádek = STAYED
# = Ondřej Benešík = YES
# = Jan Čižinský = YES
# = Pavla Golasowská = YES
# = Stanislav Juránek = YES
# = Marian Jurečka = YES
# = Vít Kaňkovský = YES
# = Jiří Mihola = YES
# = Marek Výborný = YES
#
# ===== TOP09 =====
# = Dominik Feri = YES
# = Miroslav Kalousek = YES
# = Helena Langšádlová = YES
# = Markéta Pekarová Adamová = YES
# = Karel Schwarzenberg = YES
# = František Vácha = YES
# = Vlastimil Válek = YES
#
# ===== STAN =====
# = Jan Farský = YES
# = Petr Gazdík = YES
# = Věra Kovářová = YES
# = Jana Krutáková = YES
# = Martin Půta = YES
# = Vít Rakušan = YES

# %% [markdown]
# ## python script running this logic recursively & saving data to a csv file
# ### webscraper.py & voting.csv
